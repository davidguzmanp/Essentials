# %% [markdown]
# # `transformers` meets `bitsandbytes` for democratzing Large Language Models (LLMs) through 4bit quantization
#
# <center>
# <img src="https://github.com/huggingface/blog/blob/main/assets/96_hf_bitsandbytes_integration/Thumbnail_blue.png?raw=true" alt="drawing" width="700" class="center"/>
# </center>
#
# Welcome to this notebook that goes through the recent `bitsandbytes` integration that includes the work from XXX that introduces no performance degradation 4bit quantization techniques, for democratizing LLMs inference and training.
#
# In this notebook, we will learn together how to load a large model in 4bit (`gpt-neo-x-20b`) and train it using Google Colab and PEFT library from Hugging Face 🤗.
#
# [In the general usage notebook](https://colab.research.google.com/drive/1ge2F1QSK8Q7h0hn3YKuBCOAS0bK8E0wf?usp=sharing), you can learn how to propely load a model in 4bit with all its variants.
#
# If you liked the previous work for integrating [*LLM.int8*](https://arxiv.org/abs/2208.07339), you can have a look at the [introduction blogpost](https://huggingface.co/blog/hf-bitsandbytes-integration) to lean more about that quantization method.

# %%
# !pip uninstall datasets -y
# !pip install datasets

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
# !pip install -q -U transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 70.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.5 MB/s eta 0:00:00

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 17.4 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.3 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for accelerate (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.2 MB/s eta 0:00:00

# %%
from datasets import load_dataset

# %% [markdown]
# First let's load the model we are going to use - GPT-neo-x-20B! Note that the model itself is around 40GB in half precision

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_id = "Open-Orca/Mistral-7B-OpenOrca"
#model_id = "openlm-research/open_llama_3b"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map={"":0})
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/101 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/623 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Then we have to apply some preprocessing to the model to prepare it for training. For that use the `prepare_model_for_kbit_training` method from PEFT.

# %% [markdown]
# ## Metaphor Probabilities (zero-shot) for the pretrained model

# %%
import numpy as np
from scipy.special import softmax
import pdb
import pandas as pd
import math
from typing import List
import random
import argparse
import torch


def sent_scoring(model_tokenizer, text, cuda, score_type="loss", output_attentions=False, length_normalize=False):
    model = model_tokenizer[0]
    tokenizer = model_tokenizer[1]
    assert model is not None
    assert tokenizer is not None
    encoded_text = tokenizer.encode(text)
    input_ids = torch.tensor(encoded_text).unsqueeze(0)
    if cuda:
        input_ids = input_ids.to('cuda')
    with torch.no_grad():
        outputs = model(input_ids, labels=input_ids, output_attentions=output_attentions)
    loss, logits = outputs[:2]

    sentence_prob = loss.item()
    if score_type == "prob":
        if length_normalize:
            mult = 2
        else:
            mult = len(encoded_text)

        sentence_prob = math.exp(-1.0 * loss * (mult - 1))

    if output_attentions:
        attn = outputs["attentions"]
        return sentence_prob, attn, input_ids

    return sentence_prob

def confusion_matrix(P_forward_1, P_forward_2, P_backward_1, P_backward_2):
    correct_forward = len(np.where(np.array(P_forward_1) >= 0.5)[0]) + len(np.where(np.array(P_forward_2) >=0.5)[0])
    wrong_forward = len(P_forward_1) + len(P_forward_2) - correct_forward

    correct_backward = len(np.where(np.array(P_backward_1) >= 0.5)[0]) + len(np.where(np.array(P_backward_2) >=0.5)[0])
    wrong_backward = len(P_backward_1) + len(P_backward_2) - correct_backward

    print("correct forward", correct_forward, "wrong forward", wrong_forward, "correct backward", correct_backward, "wrong_backward", wrong_backward)

def evaluate_model(model, tokenizer, test_set, middle_phrase="", use_prefix=0, verbose=True, score_type="prob", use_cuda=False, return_acc=False) -> tuple:
    preds = []
    labels = []
    x_1 = []
    x_2 = []
    y_1 = []
    y_2 = []
    P_x_1 = []
    P_x_2 = []
    P_y_1 = []
    P_y_2 = []
    P_x_1_y_1 = []
    P_x_1_y_2 = []
    P_x_2_y_1 = []
    P_x_2_y_2 = []
    P_x_1_correct = []
    P_x_2_correct = []
    P_y_1_correct = []
    P_y_2_correct = []
    correct = 0

    for i, metaphor_data in enumerate(test_set):
        ctx, p1, p2 = metaphor_data["startphrase"], metaphor_data["ending1"], metaphor_data["ending2"]
        labels.append(int(metaphor_data["labels"]))
        if use_prefix > 0:
            prefix_prompt = select_prefix_prompts(prompt_file, use_prefix) if use_prefix else ""
        else:
            prefix_prompt = ""

        sent1 = prefix_prompt + ctx + ". " + middle_phrase + p1 + "."
        sent2 = prefix_prompt + ctx + ". " + middle_phrase + p2 + "."

        score1 = sent_scoring((model, tokenizer), sent1, use_cuda, score_type=score_type)
        score2 = sent_scoring((model, tokenizer), sent2, use_cuda, score_type=score_type)

        if score_type == "loss":
            pred = 0 if score1 < score2 else 1
        else:
            pred = 1 if score1 < score2 else 0

        pred_sent = sent1 if pred == 0 else sent2

        if i % 2 == 0:
            x_1.append(ctx)
            x_1_score = sent_scoring((model, tokenizer), ctx + ".", use_cuda, score_type=score_type)
            P_x_1.append(x_1_score)
            y_1.append(p1)
            y_2.append(p2)
            y1_score = sent_scoring((model, tokenizer), p1 + ".", use_cuda, score_type=score_type)
            y2_score = sent_scoring((model, tokenizer), p2 + ".", use_cuda, score_type=score_type)
            P_y_1.append(y1_score)
            P_y_2.append(y2_score)

            P_x_1_y_1.append(score1)
            P_x_1_y_2.append(score2)
            P_x_1_correct.append(score1/(score1 + score2))

        else:
            x_2.append(ctx)
            x_2_score = sent_scoring((model, tokenizer), ctx + ".", use_cuda, score_type=score_type)
            P_x_2.append(x_2_score)
            P_x_2_y_1.append(score1)
            P_x_2_y_2.append(score2)
            P_x_2_correct.append(score2/(score1 + score2))

            P_y_1_correct.append(P_x_1_y_1[-1]/(P_x_1_y_1[-1] + score1))
            P_y_2_correct.append(score2/(P_x_1_y_2[-1] + score2))

        if verbose:
            print(f"Q: {ctx}: 1. {p1} 2. {p2}")
            print(f"model says '{pred_sent}' is more likely")
            print("\n")
        if pred == metaphor_data["labels"]:
            correct += 1
        preds.append(pred)

    cols = {"x_1": x_1, "x_2": x_2, "y_1": y_1, "y_2": y_2, "P(x_1)": P_x_1, "P(x_2)": P_x_2, "P(y_1)": P_y_1, "P(y_2)": P_y_2,
        "P(x_1, y_1)": P_x_1_y_1, "P(x_1, y_2)": P_x_1_y_2, "P(x_2, y_1)": P_x_2_y_1, "P(x_2, y_2)": P_x_2_y_2,
        "P(y_1|x_1)": P_x_1_correct, "P(y_2|x_2)": P_x_2_correct, "P(x_1|y_1)": P_y_1_correct, "P(x_2|y_2)": P_y_2_correct}
    out_df = pd.DataFrame(cols)

    if return_acc:
        return correct/len(preds), out_df, preds, labels

    return out_df, preds, labels

def compute_stats(total_df: pd.DataFrame, all_preds: List, all_labels: List) -> None:
    print("overall accuracy: ")
    print(len(np.where(np.array(all_preds) == np.array(all_labels))[0])/len(all_labels))
    print("confusion matrix: ")
    confusion_matrix(list(total_df["P(y_1|x_1)"]), list(total_df["P(y_2|x_2)"]), list(total_df["P(x_1|y_1)"]), list(total_df["P(x_2|y_2)"]))

# %%
dataset = load_dataset("nightingal3/fig-qa")
dataset['test']
# Out:
# Downloading readme:   0%|          | 0.00/3.36k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/155k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/864k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/116k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/120k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['startphrase', 'ending1', 'ending2', 'labels', 'valid'],
#     num_rows: 1146
# })

# %%
subset_test_dataset = dataset['train'].select(range(500))

# %%
out_df, preds, labels = evaluate_model(model, tokenizer, subset_test_dataset)
# Out:
# Q: Her word had the strength of titanium.: 1. Her promises can be believed. 2. Her promises cannot be trusted.
# model says 'Her word had the strength of titanium.. Her promises cannot be trusted..' is more likely
#
#
# Q: Her word had the strength of a wine glass.: 1. Her promises can be believed. 2. Her promises cannot be trusted.
# model says 'Her word had the strength of a wine glass.. Her promises cannot be trusted..' is more likely
#
#
# Q: His kisses have the passion of lovers meeting after a long separation.: 1. His kisses are demonstrative and intense. 2. His kiss is unemotional.
# model says 'His kisses have the passion of lovers meeting after a long separation.. His kiss is unemotional..' is more likely
#
#
# Q: His kisses have the passion of a couple in a loveless marriage.: 1. His kisses are demonstrative and intense. 2. His kiss is unemotional.
# model says 'His kisses have the passion of a couple in a loveless marriage.. His kiss is unemotional..' is more likely
#
#
# Q: This winter is as cold as my mother-in-law towards me: 1. It's very cold 2. It's pretty warm
# model says 'This winter is as cold as my mother-in-law towards me. It's very cold.' is more likely
#
#
# Q: This winter is as cold as Death Valley at noon: 1. It's very cold 2. It's pretty warm
# model says 'This winter is as cold as Death Valley at noon. It's very cold.' is more likely
#
#
# Q: The dog was as grumpy as an old man: 1. he was mean 2. he was nice
# model says 'The dog was as grumpy as an old man. he was mean.' is more likely
#
#
# Q: The dog was as grumpy as a kindergarten teacher: 1. he was mean 2. he was nice
# model says 'The dog was as grumpy as a kindergarten teacher. he was mean.' is more likely
#
#
# Q: The voyage was as long as a lifetime: 1. The voyage was very long 2. The voyage as short.
# model says 'The voyage was as long as a lifetime. The voyage was very long.' is more likely
#
#
# Q: The voyage was as long as the blink of an eye: 1. The voyage was very long 2. The voyage as short.
# model says 'The voyage was as long as the blink of an eye. The voyage was very long.' is more likely
#
#
# Q: He had all the wealth of a tycoon: 1. He was rich. 2. He was poor.
# model says 'He had all the wealth of a tycoon. He was rich..' is more likely
#
#
# Q: He had all the wealth of a hobo: 1. He was rich. 2. He was poor.
# model says 'He had all the wealth of a hobo. He was poor..' is more likely
#
#
# Q: It smells like a freshly baked cookies on Christmas morning: 1. It smells great 2. It smells awful
# model says 'It smells like a freshly baked cookies on Christmas morning. It smells great.' is more likely
#
#
# Q: It smells like a cesspool sitting in the hot sun: 1. It smells great 2. It smells awful
# model says 'It smells like a cesspool sitting in the hot sun. It smells awful.' is more likely
#
#
# Q: The conversation is a bank vault: 1. The conversation is worthwhile. 2. The conversation is meaningless.
# model says 'The conversation is a bank vault. The conversation is meaningless..' is more likely
#
#
# Q: The conversation is a 25 cent off coupon: 1. The conversation is worthwhile. 2. The conversation is meaningless.
# model says 'The conversation is a 25 cent off coupon. The conversation is meaningless..' is more likely
#
#
# Q: The motivational push was a bulldozer: 1. The motivational push was very motivating. 2. The motivational push didn't work well.
# model says 'The motivational push was a bulldozer. The motivational push was very motivating..' is more likely
#
#
# Q: The motivational push was a light breeze: 1. The motivational push was very motivating. 2. The motivational push didn't work well.
# model says 'The motivational push was a light breeze. The motivational push was very motivating..' is more likely
#
#
# Q: Money is a helpful stranger: 1. Money is good 2. Money is bad
# model says 'Money is a helpful stranger. Money is good.' is more likely
#
#
# Q: Money is a murderer: 1. Money is good 2. Money is bad
# model says 'Money is a murderer. Money is bad.' is more likely
#
#
# Q: The conversation was the OJ Simpson trial: 1. The conversation was long 2. The conversation was short
# model says 'The conversation was the OJ Simpson trial. The conversation was long.' is more likely
#
#
# Q: The conversation was a cigarette break: 1. The conversation was long 2. The conversation was short
# model says 'The conversation was a cigarette break. The conversation was short.' is more likely
#
#
# Q: The seas on the voyage were glass: 1. The seas were calm 2. The seas were rough
# model says 'The seas on the voyage were glass. The seas were calm.' is more likely
#
#
# Q: The seas on the voyage were a rock quarry: 1. The seas were calm 2. The seas were rough
# model says 'The seas on the voyage were a rock quarry. The seas were rough.' is more likely
#
#
# Q: The student was as helpful as medicine: 1. he was a big help 2. he was not needed
# model says 'The student was as helpful as medicine. he was a big help.' is more likely
#
#
# Q: The student was as helpful as a punch in the face: 1. he was a big help 2. he was not needed
# model says 'The student was as helpful as a punch in the face. he was a big help.' is more likely
#
#
# Q: Their relationship has the heat of Miami in August: 1. Their relationship is passionate 2. Their relationship is lacking passion.
# model says 'Their relationship has the heat of Miami in August. Their relationship is passionate.' is more likely
#
#
# Q: Their relationship has the heat of an igloo.: 1. Their relationship is passionate 2. Their relationship is lacking passion.
# model says 'Their relationship has the heat of an igloo.. Their relationship is passionate.' is more likely
#
#
# Q: The voyage will be a walk through fire.: 1. The voyage will be difficult and arduous. 2. The voyage will be pleasant.
# model says 'The voyage will be a walk through fire.. The voyage will be pleasant..' is more likely
#
#
# Q: The voyage will be a walk through flowers.: 1. The voyage will be difficult and arduous. 2. The voyage will be pleasant.
# model says 'The voyage will be a walk through flowers.. The voyage will be pleasant..' is more likely
#
#
# Q: For him, earning money was oxygen.: 1. Making money kept him alive. 2. Making money was killing him.
# model says 'For him, earning money was oxygen.. Making money kept him alive..' is more likely
#
#
# Q: For him, earning money was a rope around his neck.: 1. Making money kept him alive. 2. Making money was killing him.
# model says 'For him, earning money was a rope around his neck.. Making money was killing him..' is more likely
#
#
# Q: The speaker was as quiet as a newborn baby.: 1. The speaker was very quiet. 2. The speaker was actually rather loud.
# model says 'The speaker was as quiet as a newborn baby.. The speaker was very quiet..' is more likely
#
#
# Q: The speaker was as quiet as a freight train.: 1. The speaker was very quiet. 2. The speaker was actually rather loud.
# model says 'The speaker was as quiet as a freight train.. The speaker was very quiet..' is more likely
#
#
# Q: The man was as cool as ice: 1. The man was very cool. 2. The man wasn't cool at all.
# model says 'The man was as cool as ice. The man was very cool..' is more likely
#
#
# Q: The man was as cool as sunburn: 1. The man was very cool. 2. The man wasn't cool at all.
# model says 'The man was as cool as sunburn. The man was very cool..' is more likely
#
#
# Q: The wedding planner was an imposter.: 1. The wedding planner did a horrible job planning the wedding. 2. The wedding planner did wonderfully planning the wedding.
# model says 'The wedding planner was an imposter.. The wedding planner did a horrible job planning the wedding..' is more likely
#
#
# Q: The wedding planner was a magician.: 1. The wedding planner did a horrible job planning the wedding. 2. The wedding planner did wonderfully planning the wedding.
# model says 'The wedding planner was a magician.. The wedding planner did a horrible job planning the wedding..' is more likely
#
#
# Q: The dancer moved like a butterfly: 1. the dancer is graceful 2. The dancer is lead footed
# model says 'The dancer moved like a butterfly. the dancer is graceful.' is more likely
#
#
# Q: The dancer moved like a horse.: 1. the dancer is graceful 2. The dancer is lead footed
# model says 'The dancer moved like a horse.. the dancer is graceful.' is more likely
#
#
# Q: the pizza tastes like homemade: 1. it's delicious 2. it's garbage
# model says 'the pizza tastes like homemade. it's delicious.' is more likely
#
#
# Q: the pizza tastes like yesterdays leftovers: 1. it's delicious 2. it's garbage
# model says 'the pizza tastes like yesterdays leftovers. it's delicious.' is more likely
#
#
# Q: The painting had the creativity of a bowl of oatmeal: 1. The movie was really dull. 2. The movie was really creative.
# model says 'The painting had the creativity of a bowl of oatmeal. The movie was really dull..' is more likely
#
#
# Q: The painting had the creativity of a James Cameron movie: 1. The movie was really dull. 2. The movie was really creative.
# model says 'The painting had the creativity of a James Cameron movie. The movie was really creative..' is more likely
#
#
# Q: The child was as religious as a priest: 1. The child was very religious 2. The child was not religious
# model says 'The child was as religious as a priest. The child was very religious.' is more likely
#
#
# Q: The child was as religious as a sinner: 1. The child was very religious 2. The child was not religious
# model says 'The child was as religious as a sinner. The child was very religious.' is more likely
#
#
# Q: The woman was as kind as a teacher: 1. The woman was kind 2. The woman was cruel
# model says 'The woman was as kind as a teacher. The woman was kind.' is more likely
#
#
# Q: The woman was as kind as a prisoner: 1. The woman was kind 2. The woman was cruel
# model says 'The woman was as kind as a prisoner. The woman was kind.' is more likely
#
#
# Q: The test is as easy as a Sunday  morning: 1. the test is easy 2. the test is hard
# model says 'The test is as easy as a Sunday  morning. the test is easy.' is more likely
#
#
# Q: The test is as easy as rocket science: 1. the test is easy 2. the test is hard
# model says 'The test is as easy as rocket science. the test is easy.' is more likely
#
#
# Q: She is happy as a clam: 1. she is elated 2. she is mad
# model says 'She is happy as a clam. she is elated.' is more likely
#
#
# Q: She is happy as a bear that stepped on a thorn: 1. she is elated 2. she is mad
# model says 'She is happy as a bear that stepped on a thorn. she is mad.' is more likely
#
#
# Q: The employee is sharp as a razor: 1. The employee is smart. 2. The employee is dumb.
# model says 'The employee is sharp as a razor. The employee is smart..' is more likely
#
#
# Q: The employee is sharp as a bowling ball: 1. The employee is smart. 2. The employee is dumb.
# model says 'The employee is sharp as a bowling ball. The employee is smart..' is more likely
#
#
# Q: The tourist thought the bed at the hotel felt like velvet: 1. The bed was soft. 2. The bed was hard.
# model says 'The tourist thought the bed at the hotel felt like velvet. The bed was hard..' is more likely
#
#
# Q: The tourist thought the bed at the hotel felt like marble: 1. The bed was soft. 2. The bed was hard.
# model says 'The tourist thought the bed at the hotel felt like marble. The bed was hard..' is more likely
#
#
# Q: When the rubber hits the road. life gets real: 1. things get intense 2. things get worse
# model says 'When the rubber hits the road. life gets real. things get intense.' is more likely
#
#
# Q: When the rubber hits the road. things go  down hill: 1. things get intense 2. things get worse
# model says 'When the rubber hits the road. things go  down hill. things get worse.' is more likely
#
#
# Q: The pianist's performance was a game of whack-a-mole.: 1. The pianist's performance was sloppy. 2. The pianist's performance was meticulous.
# model says 'The pianist's performance was a game of whack-a-mole.. The pianist's performance was sloppy..' is more likely
#
#
# Q: The pianist's performance was the weaving of an ornate Persian carpet.: 1. The pianist's performance was sloppy. 2. The pianist's performance was meticulous.
# model says 'The pianist's performance was the weaving of an ornate Persian carpet.. The pianist's performance was sloppy..' is more likely
#
#
# Q: The girl's personality was as sweet as a grapefruit: 1. The girl had a very surly personality. 2. The girl had a sweet personality.
# model says 'The girl's personality was as sweet as a grapefruit. The girl had a sweet personality..' is more likely
#
#
# Q: The girl's personality was as sweet as a donut: 1. The girl had a very surly personality. 2. The girl had a sweet personality.
# model says 'The girl's personality was as sweet as a donut. The girl had a sweet personality..' is more likely
#
#
# Q: The movie had as much meaning as a Hallmark card: 1. The movie's meaning was frivolous. 2. The movie was laden with meaning.
# model says 'The movie had as much meaning as a Hallmark card. The movie was laden with meaning..' is more likely
#
#
# Q: The movie had as much meaning as the Bible: 1. The movie's meaning was frivolous. 2. The movie was laden with meaning.
# model says 'The movie had as much meaning as the Bible. The movie was laden with meaning..' is more likely
#
#
# Q: The jazz solo sounded as smooth as silk: 1. The jazz solo sounded nice and smooth 2. The jazz solo sounded rough and bad
# model says 'The jazz solo sounded as smooth as silk. The jazz solo sounded nice and smooth.' is more likely
#
#
# Q: The jazz solo sounded as smooth as sandpaper: 1. The jazz solo sounded nice and smooth 2. The jazz solo sounded rough and bad
# model says 'The jazz solo sounded as smooth as sandpaper. The jazz solo sounded nice and smooth.' is more likely
#
#
# Q: Her hangover made her feel like death: 1. Her hangover made her feel terrible. 2. Her hangover didn't hurt her at all.
# model says 'Her hangover made her feel like death. Her hangover made her feel terrible..' is more likely
#
#
# Q: Her hangover made her feel like a sunrise: 1. Her hangover made her feel terrible. 2. Her hangover didn't hurt her at all.
# model says 'Her hangover made her feel like a sunrise. Her hangover made her feel terrible..' is more likely
#
#
# Q: The room was as open as a farm.: 1. The room was very open. 2. The room wasn't open at all.
# model says 'The room was as open as a farm.. The room was very open..' is more likely
#
#
# Q: The room was as open as a city.: 1. The room was very open. 2. The room wasn't open at all.
# model says 'The room was as open as a city.. The room was very open..' is more likely
#
#
# Q: His joints have the crackle of a bowl of Rice Krispies: 1. His joints are quite crackly 2. His joints do not crackle
# model says 'His joints have the crackle of a bowl of Rice Krispies. His joints do not crackle.' is more likely
#
#
# Q: His joints have the crackle of a pre-popped roll of bubble wrap: 1. His joints are quite crackly 2. His joints do not crackle
# model says 'His joints have the crackle of a pre-popped roll of bubble wrap. His joints do not crackle.' is more likely
#
#
# Q: The lightbulb is putting out the light of a massive forest fire on a dark night: 1. The lightbulb is putting out a lot of light 2. The lightbulb is putting out no light
# model says 'The lightbulb is putting out the light of a massive forest fire on a dark night. The lightbulb is putting out a lot of light.' is more likely
#
#
# Q: The lightbulb is putting out the light of a massive black hole in the darkness of space: 1. The lightbulb is putting out a lot of light 2. The lightbulb is putting out no light
# model says 'The lightbulb is putting out the light of a massive black hole in the darkness of space. The lightbulb is putting out a lot of light.' is more likely
#
#
# Q: The thrift store had the variety of a monochrome print.: 1. The thrift store had a limited selection. 2. The thrift store had a varied selection.
# model says 'The thrift store had the variety of a monochrome print.. The thrift store had a limited selection..' is more likely
#
#
# Q: The thrift store had the variety of a dazzling tapestry.: 1. The thrift store had a limited selection. 2. The thrift store had a varied selection.
# model says 'The thrift store had the variety of a dazzling tapestry.. The thrift store had a limited selection..' is more likely
#
#
# Q: The doctor was a Norse villain.: 1. The doctor was mean. 2. The doctor was kind and charming.
# model says 'The doctor was a Norse villain.. The doctor was mean..' is more likely
#
#
# Q: The doctor was a fairytale prince.: 1. The doctor was mean. 2. The doctor was kind and charming.
# model says 'The doctor was a fairytale prince.. The doctor was mean..' is more likely
#
#
# Q: The sound of the glass shattering was like Hiroshima: 1. The sound was loud 2. The sound was quiet
# model says 'The sound of the glass shattering was like Hiroshima. The sound was loud.' is more likely
#
#
# Q: The sound of the glass shattering was like a lullaby: 1. The sound was loud 2. The sound was quiet
# model says 'The sound of the glass shattering was like a lullaby. The sound was loud.' is more likely
#
#
# Q: She was a bear at dinner: 1. She ate a lot 2. She ate very little
# model says 'She was a bear at dinner. She ate a lot.' is more likely
#
#
# Q: She was a mouse at dinner: 1. She ate a lot 2. She ate very little
# model says 'She was a mouse at dinner. She ate very little.' is more likely
#
#
# Q: The armor was tough as iron: 1. The armor was tough 2. The armor was breakable and weak
# model says 'The armor was tough as iron. The armor was tough.' is more likely
#
#
# Q: The armor was tough as glass: 1. The armor was tough 2. The armor was breakable and weak
# model says 'The armor was tough as glass. The armor was tough.' is more likely
#
#
# Q: The toy was cared for like a baby: 1. The toy was taken good care of 2. The toy was not cared for well at all.
# model says 'The toy was cared for like a baby. The toy was taken good care of.' is more likely
#
#
# Q: The toy was cared for like trash: 1. The toy was taken good care of 2. The toy was not cared for well at all.
# model says 'The toy was cared for like trash. The toy was taken good care of.' is more likely
#
#
# Q: The lawyer's negotiation tactics were like steel: 1. The lawyer's negotiation tactics were tough. 2. The lawyer's negotiation tactics were lenient.
# model says 'The lawyer's negotiation tactics were like steel. The lawyer's negotiation tactics were tough..' is more likely
#
#
# Q: The lawyer's negotiation tactics were like a fuzzy bathrobe: 1. The lawyer's negotiation tactics were tough. 2. The lawyer's negotiation tactics were lenient.
# model says 'The lawyer's negotiation tactics were like a fuzzy bathrobe. The lawyer's negotiation tactics were tough..' is more likely
#
#
# Q: The plastic plate shattered and looked like A spiderweb: 1. It shattered into a lot of pieces. 2. It only shattered into 2 pieces.
# model says 'The plastic plate shattered and looked like A spiderweb. It shattered into a lot of pieces..' is more likely
#
#
# Q: The plastic plate shattered and looked like A half moon: 1. It shattered into a lot of pieces. 2. It only shattered into 2 pieces.
# model says 'The plastic plate shattered and looked like A half moon. It shattered into a lot of pieces..' is more likely
#
#
# Q: The apartment was as high up as The empire State building observation deck.: 1. The apartment was on the high floor. 2. The apartment was only a few floors up
# model says 'The apartment was as high up as The empire State building observation deck.. The apartment was on the high floor..' is more likely
#
#
# Q: The apartment was as high up as A treehouse in the backyard: 1. The apartment was on the high floor. 2. The apartment was only a few floors up
# model says 'The apartment was as high up as A treehouse in the backyard. The apartment was only a few floors up.' is more likely
#
#
# Q: The man had the features of a Greek god: 1. The man was very attractive 2. The man was goofy and ugly
# model says 'The man had the features of a Greek god. The man was very attractive.' is more likely
#
#
# Q: The man had the features of a clown: 1. The man was very attractive 2. The man was goofy and ugly
# model says 'The man had the features of a clown. The man was very attractive.' is more likely
#
#
# Q: The pug was wheezing in dog form.: 1. The dog is tired and has trouble breathing. 2. The dog has a ton of energy.
# model says 'The pug was wheezing in dog form.. The dog has a ton of energy..' is more likely
#
#
# Q: The pug was lightning in dog form.: 1. The dog is tired and has trouble breathing. 2. The dog has a ton of energy.
# model says 'The pug was lightning in dog form.. The dog has a ton of energy..' is more likely
#
#
# Q: That movie has the humor of a nun.: 1. The movie is not funny. 2. The movie is very funny.
# model says 'That movie has the humor of a nun.. The movie is not funny..' is more likely
#
#
# Q: That movie has the humor of a clown bus.: 1. The movie is not funny. 2. The movie is very funny.
# model says 'That movie has the humor of a clown bus.. The movie is not funny..' is more likely
#
#
# Q: The movie has a depth of A crater.: 1. The movie has a deep meaning. 2. The movie is superficial.
# model says 'The movie has a depth of A crater.. The movie has a deep meaning..' is more likely
#
#
# Q: The movie has a depth of A crack.: 1. The movie has a deep meaning. 2. The movie is superficial.
# model says 'The movie has a depth of A crack.. The movie has a deep meaning..' is more likely
#
#
# Q: The gambler thought his odds were as low as the ground.: 1. His odds were low. 2. His odds were actually high.
# model says 'The gambler thought his odds were as low as the ground.. His odds were low..' is more likely
#
#
# Q: The gambler thought his odds were as low as the moon.: 1. His odds were low. 2. His odds were actually high.
# model says 'The gambler thought his odds were as low as the moon.. His odds were low..' is more likely
#
#
# Q: The dancer was as graceful as a swan.: 1. The dancer was graceful. 2. The dancer was boorish and uncoordinated.
# model says 'The dancer was as graceful as a swan.. The dancer was graceful..' is more likely
#
#
# Q: The dancer was as graceful as a honking goose.: 1. The dancer was graceful. 2. The dancer was boorish and uncoordinated.
# model says 'The dancer was as graceful as a honking goose.. The dancer was graceful..' is more likely
#
#
# Q: He was as smart as A tree stump: 1. The person is dumb 2. The person is a genius
# model says 'He was as smart as A tree stump. The person is dumb.' is more likely
#
#
# Q: He was as smart as EINSTEIN: 1. The person is dumb 2. The person is a genius
# model says 'He was as smart as EINSTEIN. The person is a genius.' is more likely
#
#
# Q: The stock value was a geyser: 1. The stock value increased. 2. The stock value stayed stagnant.
# model says 'The stock value was a geyser. The stock value increased..' is more likely
#
#
# Q: The stock value was a puddle: 1. The stock value increased. 2. The stock value stayed stagnant.
# model says 'The stock value was a puddle. The stock value increased..' is more likely
#
#
# Q: The couch had all the comfort of a thornbush.: 1. The couch was very comfortable. 2. The couch was not very comfortable.
# model says 'The couch had all the comfort of a thornbush.. The couch was very comfortable..' is more likely
#
#
# Q: The couch had all the comfort of a grandma's hug.: 1. The couch was very comfortable. 2. The couch was not very comfortable.
# model says 'The couch had all the comfort of a grandma's hug.. The couch was very comfortable..' is more likely
#
#
# Q: The ballerina has all to grace of A club-footed drunk: 1. The ballerina is clumsy 2. The ballerina is graceful
# model says 'The ballerina has all to grace of A club-footed drunk. The ballerina is clumsy.' is more likely
#
#
# Q: The ballerina has all to grace of A swan gently swimming in a pond: 1. The ballerina is clumsy 2. The ballerina is graceful
# model says 'The ballerina has all to grace of A swan gently swimming in a pond. The ballerina is graceful.' is more likely
#
#
# Q: The tennis match contained all the suspense of A boring and endless Monopoly game: 1. The tennis match is tedious and boring 2. The tennis match is suspenseful and exciting
# model says 'The tennis match contained all the suspense of A boring and endless Monopoly game. The tennis match is tedious and boring.' is more likely
#
#
# Q: The tennis match contained all the suspense of An Alfred Hitchcock movie: 1. The tennis match is tedious and boring 2. The tennis match is suspenseful and exciting
# model says 'The tennis match contained all the suspense of An Alfred Hitchcock movie. The tennis match is suspenseful and exciting.' is more likely
#
#
# Q: He is faithful as a church goer: 1. he is good 2. he is bad
# model says 'He is faithful as a church goer. he is good.' is more likely
#
#
# Q: He is faithful as a strip club VIP: 1. he is good 2. he is bad
# model says 'He is faithful as a strip club VIP. he is good.' is more likely
#
#
# Q: The incense had the smell of a homemade apple pie after skipping lunch: 1. The incense smelled quite good 2. The incense didn't smell good at all
# model says 'The incense had the smell of a homemade apple pie after skipping lunch. The incense didn't smell good at all.' is more likely
#
#
# Q: The incense had the smell of a wet dog wearing gym socks: 1. The incense smelled quite good 2. The incense didn't smell good at all
# model says 'The incense had the smell of a wet dog wearing gym socks. The incense didn't smell good at all.' is more likely
#
#
# Q: The girl had the thirst of a man after finishing a 128 oz slushie: 1. The girl was not thirsty 2. The girl was very thirsty
# model says 'The girl had the thirst of a man after finishing a 128 oz slushie. The girl was very thirsty.' is more likely
#
#
# Q: The girl had the thirst of a mid-'00s SUV after a short drive: 1. The girl was not thirsty 2. The girl was very thirsty
# model says 'The girl had the thirst of a mid-'00s SUV after a short drive. The girl was very thirsty.' is more likely
#
#
# Q: The backpack had the space of a school bus in the middle of the night: 1. The backpack had a lot of space 2. There was little space in the backpack
# model says 'The backpack had the space of a school bus in the middle of the night. The backpack had a lot of space.' is more likely
#
#
# Q: The backpack had the space of a school bus on a field trip to a pizza party: 1. The backpack had a lot of space 2. There was little space in the backpack
# model says 'The backpack had the space of a school bus on a field trip to a pizza party. The backpack had a lot of space.' is more likely
#
#
# Q: The coffee was as strong as an army: 1. The coffee was very strong 2. The coffee was very weak
# model says 'The coffee was as strong as an army. The coffee was very strong.' is more likely
#
#
# Q: The coffee was as strong as diluted milk: 1. The coffee was very strong 2. The coffee was very weak
# model says 'The coffee was as strong as diluted milk. The coffee was very strong.' is more likely
#
#
# Q: The room was as dark as a pay phone: 1. The room was very dark 2. The room was not dark, but not well lit
# model says 'The room was as dark as a pay phone. The room was very dark.' is more likely
#
#
# Q: The room was as dark as a raincloud: 1. The room was very dark 2. The room was not dark, but not well lit
# model says 'The room was as dark as a raincloud. The room was very dark.' is more likely
#
#
# Q: The sun shined like a flame.: 1. The sun was very bright. 2. The sun was dim or obscured, not bright at all.
# model says 'The sun shined like a flame.. The sun was very bright..' is more likely
#
#
# Q: The sun shined like a burned-out bulb.: 1. The sun was very bright. 2. The sun was dim or obscured, not bright at all.
# model says 'The sun shined like a burned-out bulb.. The sun was very bright..' is more likely
#
#
# Q: Christmas was as lively as a party.: 1. Christmas was lively and festive. 2. Christmas was quiet, lonely, and devoid of activity.
# model says 'Christmas was as lively as a party.. Christmas was lively and festive..' is more likely
#
#
# Q: Christmas was as lively as a morgue.: 1. Christmas was lively and festive. 2. Christmas was quiet, lonely, and devoid of activity.
# model says 'Christmas was as lively as a morgue.. Christmas was lively and festive..' is more likely
#
#
# Q: The movie has the thrill of a dentist's visit: 1. The movie is dull. 2. The movie is exciting.
# model says 'The movie has the thrill of a dentist's visit. The movie is exciting..' is more likely
#
#
# Q: The movie has the thrill of a carnival ride: 1. The movie is dull. 2. The movie is exciting.
# model says 'The movie has the thrill of a carnival ride. The movie is exciting..' is more likely
#
#
# Q: The book plot has the novelty of an iPhone 4: 1. The book plot is stale. 2. The book plot is really novel.
# model says 'The book plot has the novelty of an iPhone 4. The book plot is stale..' is more likely
#
#
# Q: The book plot has the novelty of a robot with feelings: 1. The book plot is stale. 2. The book plot is really novel.
# model says 'The book plot has the novelty of a robot with feelings. The book plot is really novel..' is more likely
#
#
# Q: My shoulder hurts as much as stepping on a jagged, rusty nail: 1. It hurts a lot 2. It barely hurts at all
# model says 'My shoulder hurts as much as stepping on a jagged, rusty nail. It hurts a lot.' is more likely
#
#
# Q: My shoulder hurts as much as getting hit with a silk pillow: 1. It hurts a lot 2. It barely hurts at all
# model says 'My shoulder hurts as much as getting hit with a silk pillow. It hurts a lot.' is more likely
#
#
# Q: The hostess is a dental drill.: 1. The hostess is unpleasant. 2. The hostess is delightful.
# model says 'The hostess is a dental drill.. The hostess is unpleasant..' is more likely
#
#
# Q: The hostess is a sweet potato pie.: 1. The hostess is unpleasant. 2. The hostess is delightful.
# model says 'The hostess is a sweet potato pie.. The hostess is delightful..' is more likely
#
#
# Q: The wrinkle cream is an outhouse.: 1. The wrinkle cream is disgusting. 2. The wrinkle cream is pleasant.
# model says 'The wrinkle cream is an outhouse.. The wrinkle cream is disgusting..' is more likely
#
#
# Q: The wrinkle cream is a purring kitten.: 1. The wrinkle cream is disgusting. 2. The wrinkle cream is pleasant.
# model says 'The wrinkle cream is a purring kitten.. The wrinkle cream is pleasant..' is more likely
#
#
# Q: She was gleaming like headlights: 1. she was bright 2. she was dark
# model says 'She was gleaming like headlights. she was bright.' is more likely
#
#
# Q: She was gleaming like midnight: 1. she was bright 2. she was dark
# model says 'She was gleaming like midnight. she was dark.' is more likely
#
#
# Q: This sand is as coarse as a silkworm's thread: 1. It's not coarse at all 2. It's very rough
# model says 'This sand is as coarse as a silkworm's thread. It's very rough.' is more likely
#
#
# Q: This sand is as coarse as the discourse at a Thanksgiving dinner: 1. It's not coarse at all 2. It's very rough
# model says 'This sand is as coarse as the discourse at a Thanksgiving dinner. It's very rough.' is more likely
#
#
# Q: The pool has the wetness of the planet Kamino: 1. It's very wet 2. It's very dry
# model says 'The pool has the wetness of the planet Kamino. It's very wet.' is more likely
#
#
# Q: The pool has the wetness of the planet Tatooine: 1. It's very wet 2. It's very dry
# model says 'The pool has the wetness of the planet Tatooine. It's very wet.' is more likely
#
#
# Q: Quitting the job was as satisfying as an ice cream cone on a summer day: 1. Quitting the job was totally satisfying. 2. Quitting the job gave no satisfaction.
# model says 'Quitting the job was as satisfying as an ice cream cone on a summer day. Quitting the job was totally satisfying..' is more likely
#
#
# Q: Quitting the job was as satisfying as a prickly rose bush: 1. Quitting the job was totally satisfying. 2. Quitting the job gave no satisfaction.
# model says 'Quitting the job was as satisfying as a prickly rose bush. Quitting the job was totally satisfying..' is more likely
#
#
# Q: The music has the sound of a jackhammer: 1. The music is loud 2. The music is soft
# model says 'The music has the sound of a jackhammer. The music is loud.' is more likely
#
#
# Q: The music has the sound of a baby bird: 1. The music is loud 2. The music is soft
# model says 'The music has the sound of a baby bird. The music is soft.' is more likely
#
#
# Q: The jacket has the feeling of sandpaper: 1. The jacket is rough 2. The jacket is smooth
# model says 'The jacket has the feeling of sandpaper. The jacket is smooth.' is more likely
#
#
# Q: The jacket has the feeling of butter: 1. The jacket is rough 2. The jacket is smooth
# model says 'The jacket has the feeling of butter. The jacket is smooth.' is more likely
#
#
# Q: She was skilled like a scientist.: 1. She was very skilled. 2. She was not at all skillful.
# model says 'She was skilled like a scientist.. She was very skilled..' is more likely
#
#
# Q: She was skilled like a bum.: 1. She was very skilled. 2. She was not at all skillful.
# model says 'She was skilled like a bum.. She was very skilled..' is more likely
#
#
# Q: His vision was as cloudy as the sky during a hurricane: 1. It is hard to see through 2. it is clear
# model says 'His vision was as cloudy as the sky during a hurricane. It is hard to see through.' is more likely
#
#
# Q: His vision was as cloudy as a glass of water: 1. It is hard to see through 2. it is clear
# model says 'His vision was as cloudy as a glass of water. It is hard to see through.' is more likely
#
#
# Q: She is as clumsy as an octopus on roller skates: 1. she is a klutz 2. she is careful
# model says 'She is as clumsy as an octopus on roller skates. she is a klutz.' is more likely
#
#
# Q: She is as clumsy as a squirrel in a tree: 1. she is a klutz 2. she is careful
# model says 'She is as clumsy as a squirrel in a tree. she is a klutz.' is more likely
#
#
# Q: The teacher had all the charisma of a leader: 1. The teacher was charismatic 2. The teacher was foolish
# model says 'The teacher had all the charisma of a leader. The teacher was charismatic.' is more likely
#
#
# Q: The teacher had all the charisma of a clown: 1. The teacher was charismatic 2. The teacher was foolish
# model says 'The teacher had all the charisma of a clown. The teacher was charismatic.' is more likely
#
#
# Q: The pie crust was as flaky as dandruff: 1. The pie crust was totally flaky. 2. The pie crust was tough.
# model says 'The pie crust was as flaky as dandruff. The pie crust was tough..' is more likely
#
#
# Q: The pie crust was as flaky as a lead block: 1. The pie crust was totally flaky. 2. The pie crust was tough.
# model says 'The pie crust was as flaky as a lead block. The pie crust was tough..' is more likely
#
#
# Q: The movie ending made as much sense as a pig in a pen: 1. The movie ending made total sense. 2. The movie ending didn't make any sense.
# model says 'The movie ending made as much sense as a pig in a pen. The movie ending didn't make any sense..' is more likely
#
#
# Q: The movie ending made as much sense as a fish on a mountain: 1. The movie ending made total sense. 2. The movie ending didn't make any sense.
# model says 'The movie ending made as much sense as a fish on a mountain. The movie ending didn't make any sense..' is more likely
#
#
# Q: The ski slope is a dimple.: 1. The ski slope is easy. 2. The ski slope is difficult.
# model says 'The ski slope is a dimple.. The ski slope is easy..' is more likely
#
#
# Q: The ski slope is Cyrano De Bergerac's nose.: 1. The ski slope is easy. 2. The ski slope is difficult.
# model says 'The ski slope is Cyrano De Bergerac's nose.. The ski slope is easy..' is more likely
#
#
# Q: She was as free as a bird.: 1. She was very free. 2. She wasn't free at all.
# model says 'She was as free as a bird.. She was very free..' is more likely
#
#
# Q: She was as free as a zoo animal.: 1. She was very free. 2. She wasn't free at all.
# model says 'She was as free as a zoo animal.. She was very free..' is more likely
#
#
# Q: She was as entertaining as a lecture.: 1. She wasn't entertaining. 2. She was very entertaining.
# model says 'She was as entertaining as a lecture.. She was very entertaining..' is more likely
#
#
# Q: She was as entertaining as a television show.: 1. She wasn't entertaining. 2. She was very entertaining.
# model says 'She was as entertaining as a television show.. She was very entertaining..' is more likely
#
#
# Q: Getting the whole school evacuated in a raging fire is as easy as counting ten pennies: 1. Getting the whole school evacuated in a raging fire is simple. 2. Getting the whole school evacuated in a raging fire is nearly impossible
# model says 'Getting the whole school evacuated in a raging fire is as easy as counting ten pennies. Getting the whole school evacuated in a raging fire is nearly impossible.' is more likely
#
#
# Q: Getting the whole school evacuated in a raging fire is as easy as climbing the Swiss Alps.: 1. Getting the whole school evacuated in a raging fire is simple. 2. Getting the whole school evacuated in a raging fire is nearly impossible
# model says 'Getting the whole school evacuated in a raging fire is as easy as climbing the Swiss Alps.. Getting the whole school evacuated in a raging fire is nearly impossible.' is more likely
#
#
# Q: The building is as well constructed as the straw house  the pigs built that the wolf blew down: 1. The building is falling apart 2. The building is 100% safe
# model says 'The building is as well constructed as the straw house  the pigs built that the wolf blew down. The building is falling apart.' is more likely
#
#
# Q: The building is as well constructed as The brick house the wolf could not blow doen: 1. The building is falling apart 2. The building is 100% safe
# model says 'The building is as well constructed as The brick house the wolf could not blow doen. The building is falling apart.' is more likely
#
#
# Q: The head of our country is as smart as a a turkey: 1. The head of our country is very dumb. 2. The head of our country is very smart.
# model says 'The head of our country is as smart as a a turkey. The head of our country is very smart..' is more likely
#
#
# Q: The head of our country is as smart as an orangutang: 1. The head of our country is very dumb. 2. The head of our country is very smart.
# model says 'The head of our country is as smart as an orangutang. The head of our country is very smart..' is more likely
#
#
# Q: The future is as bright as the sun: 1. The future is bright 2. The future is not bright
# model says 'The future is as bright as the sun. The future is bright.' is more likely
#
#
# Q: The future is as bright as ink: 1. The future is bright 2. The future is not bright
# model says 'The future is as bright as ink. The future is bright.' is more likely
#
#
# Q: The cat had the fur of a Yeti: 1. The cat was furry 2. The cat was not furry
# model says 'The cat had the fur of a Yeti. The cat was furry.' is more likely
#
#
# Q: The cat had the fur of a baby's bottom: 1. The cat was furry 2. The cat was not furry
# model says 'The cat had the fur of a baby's bottom. The cat was furry.' is more likely
#
#
# Q: She thinks of herself as the mother of humanity.: 1. She is self-righteous and entitled. 2. She is humble and respectful towards the different people.
# model says 'She thinks of herself as the mother of humanity.. She is self-righteous and entitled..' is more likely
#
#
# Q: She thinks of herself as a particle of sand in the desert.: 1. She is self-righteous and entitled. 2. She is humble and respectful towards the different people.
# model says 'She thinks of herself as a particle of sand in the desert.. She is self-righteous and entitled..' is more likely
#
#
# Q: He was as cautious as a mother with a newborn: 1. he is careful 2. he is reckless
# model says 'He was as cautious as a mother with a newborn. he is careful.' is more likely
#
#
# Q: He was as cautious as a drunk driver on the highway: 1. he is careful 2. he is reckless
# model says 'He was as cautious as a drunk driver on the highway. he is reckless.' is more likely
#
#
# Q: The dog is as charming as a salesman: 1. the dog is flattering 2. the dog is gross
# model says 'The dog is as charming as a salesman. the dog is flattering.' is more likely
#
#
# Q: The dog is as charming as a sick racoon: 1. the dog is flattering 2. the dog is gross
# model says 'The dog is as charming as a sick racoon. the dog is gross.' is more likely
#
#
# Q: The girl is as cheerful as a kid in a toy store: 1. she is happy 2. she is sad
# model says 'The girl is as cheerful as a kid in a toy store. she is happy.' is more likely
#
#
# Q: The girl is as cheerful as a mom at a funeral: 1. she is happy 2. she is sad
# model says 'The girl is as cheerful as a mom at a funeral. she is happy.' is more likely
#
#
# Q: The bathroom has the space of Neptune's orbit around the sun: 1. The bathroom is spacious 2. The bathroom is cramped
# model says 'The bathroom has the space of Neptune's orbit around the sun. The bathroom is spacious.' is more likely
#
#
# Q: The bathroom has the space of an egg with a baby chicken in it: 1. The bathroom is spacious 2. The bathroom is cramped
# model says 'The bathroom has the space of an egg with a baby chicken in it. The bathroom is cramped.' is more likely
#
#
# Q: Her beauty is like the vaquita.: 1. Her beauty is quite rare. 2. Her beauty is pretty common.
# model says 'Her beauty is like the vaquita.. Her beauty is quite rare..' is more likely
#
#
# Q: Her beauty is like the Peruvian anchoveta.: 1. Her beauty is quite rare. 2. Her beauty is pretty common.
# model says 'Her beauty is like the Peruvian anchoveta.. Her beauty is quite rare..' is more likely
#
#
# Q: The boys are feeling like burrowing shrews today.: 1. The boys are very active today. 2. The boys are moving sluggish today.
# model says 'The boys are feeling like burrowing shrews today.. The boys are very active today..' is more likely
#
#
# Q: The boys are feeling like nurse sharks today.: 1. The boys are very active today. 2. The boys are moving sluggish today.
# model says 'The boys are feeling like nurse sharks today.. The boys are very active today..' is more likely
#
#
# Q: The disease was as serious as a funeral: 1. The disease was very serious 2. The disease was not serious
# model says 'The disease was as serious as a funeral. The disease was very serious.' is more likely
#
#
# Q: The disease was as serious as a hangnail: 1. The disease was very serious 2. The disease was not serious
# model says 'The disease was as serious as a hangnail. The disease was not serious.' is more likely
#
#
# Q: The doctor was dressed like Liberace: 1. The doctor was dressed well 2. The doctor was dressed poorly
# model says 'The doctor was dressed like Liberace. The doctor was dressed well.' is more likely
#
#
# Q: The doctor was dressed like a car repairman: 1. The doctor was dressed well 2. The doctor was dressed poorly
# model says 'The doctor was dressed like a car repairman. The doctor was dressed well.' is more likely
#
#
# Q: The reporter has the charisma of a sloth: 1. The reporter is boring 2. The report is over excited
# model says 'The reporter has the charisma of a sloth. The reporter is boring.' is more likely
#
#
# Q: The reporter has the charisma of a Jack Russel terrier: 1. The reporter is boring 2. The report is over excited
# model says 'The reporter has the charisma of a Jack Russel terrier. The reporter is boring.' is more likely
#
#
# Q: The wood floor is as slippery as a piece of sand paper: 1. The floor is not slippery at all 2. The floor is super slippery.
# model says 'The wood floor is as slippery as a piece of sand paper. The floor is not slippery at all.' is more likely
#
#
# Q: The wood floor is as slippery as a banana peel: 1. The floor is not slippery at all 2. The floor is super slippery.
# model says 'The wood floor is as slippery as a banana peel. The floor is not slippery at all.' is more likely
#
#
# Q: The reporter was so high he could hunt ducks with a rake: 1. The reporter was under the influence of drugs 2. The reporter was not drugged at all.
# model says 'The reporter was so high he could hunt ducks with a rake. The reporter was under the influence of drugs.' is more likely
#
#
# Q: The reporter was so high he could do differential equations with ease: 1. The reporter was under the influence of drugs 2. The reporter was not drugged at all.
# model says 'The reporter was so high he could do differential equations with ease. The reporter was under the influence of drugs.' is more likely
#
#
# Q: The gorilla tape was sticky like melted chocolate bars in a wrapper.: 1. The tape was gooey and unwilling to release 2. The tape was dry and fluffy
# model says 'The gorilla tape was sticky like melted chocolate bars in a wrapper.. The tape was dry and fluffy.' is more likely
#
#
# Q: The gorilla tape was sticky like dried mouse nest material.: 1. The tape was gooey and unwilling to release 2. The tape was dry and fluffy
# model says 'The gorilla tape was sticky like dried mouse nest material.. The tape was dry and fluffy.' is more likely
#
#
# Q: Death, the harvester of souls, waited outside the door like a drooling dog sitting at the base of a tree waiting for a squirrel.: 1. Death was patiently waiting 2. Death ran around in every direction simultaneously.
# model says 'Death, the harvester of souls, waited outside the door like a drooling dog sitting at the base of a tree waiting for a squirrel.. Death was patiently waiting.' is more likely
#
#
# Q: Death, the harvester of souls, waited outside the door like a kindergarten class that ran out of Ritalin while in a puppy farm: 1. Death was patiently waiting 2. Death ran around in every direction simultaneously.
# model says 'Death, the harvester of souls, waited outside the door like a kindergarten class that ran out of Ritalin while in a puppy farm. Death was patiently waiting.' is more likely
#
#
# Q: On the field, the soccer player was a tornado: 1. On the field, the soccer player was very aggressive. 2. On the field, the soccer player wasn't very impactful.
# model says 'On the field, the soccer player was a tornado. On the field, the soccer player was very aggressive..' is more likely
#
#
# Q: On the field, the soccer player was a light breeze: 1. On the field, the soccer player was very aggressive. 2. On the field, the soccer player wasn't very impactful.
# model says 'On the field, the soccer player was a light breeze. On the field, the soccer player was very aggressive..' is more likely
#
#
# Q: The wine tasted of my lover's lips: 1. The wine tasted great. 2. The wine tasted lousy.
# model says 'The wine tasted of my lover's lips. The wine tasted great..' is more likely
#
#
# Q: The wine tasted of old shoes: 1. The wine tasted great. 2. The wine tasted lousy.
# model says 'The wine tasted of old shoes. The wine tasted great..' is more likely
#
#
# Q: The effects of the disease on her body was an earthquake: 1. The effects were devestating 2. The effects were minimal
# model says 'The effects of the disease on her body was an earthquake. The effects were minimal.' is more likely
#
#
# Q: The effects of the disease on her body was a raindrop: 1. The effects were devestating 2. The effects were minimal
# model says 'The effects of the disease on her body was a raindrop. The effects were minimal.' is more likely
#
#
# Q: The article from the reporter has the insights of A first grader's primer: 1. The article is shallow and lacks depth 2. The article is deep and meaningful
# model says 'The article from the reporter has the insights of A first grader's primer. The article is deep and meaningful.' is more likely
#
#
# Q: The article from the reporter has the insights of An expert journalist: 1. The article is shallow and lacks depth 2. The article is deep and meaningful
# model says 'The article from the reporter has the insights of An expert journalist. The article is deep and meaningful.' is more likely
#
#
# Q: Her cheeks were the color of a delicate rose: 1. Her cheeks were pink 2. Her cheeks were white
# model says 'Her cheeks were the color of a delicate rose. Her cheeks were pink.' is more likely
#
#
# Q: Her cheeks were the color of chalk: 1. Her cheeks were pink 2. Her cheeks were white
# model says 'Her cheeks were the color of chalk. Her cheeks were white.' is more likely
#
#
# Q: He's busy as a beaver: 1. He's busy. 2. He's lazy, not busy at all.
# model says 'He's busy as a beaver. He's busy..' is more likely
#
#
# Q: He's busy as a sloth: 1. He's busy. 2. He's lazy, not busy at all.
# ...
#
#
# Q: Dinner was a symphony: 1. The dinner was delightful and full of complex flavors that all worked well together 2. The dinner was boring with little flavor
# model says 'Dinner was a symphony. The dinner was boring with little flavor.' is more likely
#
#
# Q: Dinner was as flat as a single note played on a recorder: 1. The dinner was delightful and full of complex flavors that all worked well together 2. The dinner was boring with little flavor
# model says 'Dinner was as flat as a single note played on a recorder. The dinner was boring with little flavor.' is more likely
#
#
# Q: The homework was as difficult as rocket science: 1. The homework was difficult 2. The homework was simple.
# model says 'The homework was as difficult as rocket science. The homework was difficult.' is more likely
#
#
# Q: The homework was as difficult as saying your alphabet: 1. The homework was difficult 2. The homework was simple.
# model says 'The homework was as difficult as saying your alphabet. The homework was difficult.' is more likely
#
#
# Q: He weighs as much as a thimble.: 1. He is very light. 2. He is very heavy.
# model says 'He weighs as much as a thimble.. He is very light..' is more likely
#
#
# Q: He weighs as much as a building.: 1. He is very light. 2. He is very heavy.
# model says 'He weighs as much as a building.. He is very heavy..' is more likely
#
#
# Q: The stove had the heat of the Chernobyl power plant right after the meltdown: 1. The stove is very hot 2. The stove is cold
# model says 'The stove had the heat of the Chernobyl power plant right after the meltdown. The stove is very hot.' is more likely
#
#
# Q: The stove had the heat of Walt Disney's cryogenically frozen body: 1. The stove is very hot 2. The stove is cold
# model says 'The stove had the heat of Walt Disney's cryogenically frozen body. The stove is cold.' is more likely
#
#
# Q: The computer had the processing power of an android Einstein: 1. The computer has a lot of processing power 2. The computer has a low amount of processing power
# model says 'The computer had the processing power of an android Einstein. The computer has a lot of processing power.' is more likely
#
#
# Q: The computer had the processing power of a deformed dodo clone: 1. The computer has a lot of processing power 2. The computer has a low amount of processing power
# model says 'The computer had the processing power of a deformed dodo clone. The computer has a lot of processing power.' is more likely
#
#
# Q: The novel has the morality of a brothel: 1. The novel is immoral 2. The novel is pious
# model says 'The novel has the morality of a brothel. The novel is immoral.' is more likely
#
#
# Q: The novel has the morality of a saint: 1. The novel is immoral 2. The novel is pious
# model says 'The novel has the morality of a saint. The novel is immoral.' is more likely
#
#
# Q: The town has the rules of Cinderella's step-mother.: 1. The town is very strict and demanding. 2. The town is very lenient in its rules.
# model says 'The town has the rules of Cinderella's step-mother.. The town is very strict and demanding..' is more likely
#
#
# Q: The town has the rules of a 60s hippie.: 1. The town is very strict and demanding. 2. The town is very lenient in its rules.
# model says 'The town has the rules of a 60s hippie.. The town is very strict and demanding..' is more likely
#
#
# Q: He had the morality of a saint: 1. He was a very moral person 2. He was a very immoral person.
# model says 'He had the morality of a saint. He was a very moral person.' is more likely
#
#
# Q: He had the morality of a devil: 1. He was a very moral person 2. He was a very immoral person.
# model says 'He had the morality of a devil. He was a very moral person.' is more likely
#
#
# Q: He was as desirable as gold: 1. He was very desirable 2. He was very undesirable
# model says 'He was as desirable as gold. He was very desirable.' is more likely
#
#
# Q: He was as desirable as the flu: 1. He was very desirable 2. He was very undesirable
# model says 'He was as desirable as the flu. He was very desirable.' is more likely
#
#
# Q: The soccer team is the London symphony: 1. The soccer team is extremely well-coordinated. 2. The soccer team is poorly coordinated and chaotic.
# model says 'The soccer team is the London symphony. The soccer team is extremely well-coordinated..' is more likely
#
#
# Q: The soccer team is a night club: 1. The soccer team is extremely well-coordinated. 2. The soccer team is poorly coordinated and chaotic.
# model says 'The soccer team is a night club. The soccer team is extremely well-coordinated..' is more likely
#
#
# Q: His dedication was built out of stone pillars.: 1. He was very dedicated. 2. He was not very dedicated.
# model says 'His dedication was built out of stone pillars.. He was very dedicated..' is more likely
#
#
# Q: His dedication was built out of cardboard.: 1. He was very dedicated. 2. He was not very dedicated.
# model says 'His dedication was built out of cardboard.. He was very dedicated..' is more likely
#
#
# Q: She ran as fast as a bullet: 1. She ran fast 2. She ran slowly
# model says 'She ran as fast as a bullet. She ran fast.' is more likely
#
#
# Q: She ran as fast as a snail: 1. She ran fast 2. She ran slowly
# model says 'She ran as fast as a snail. She ran fast.' is more likely
#
#
# Q: His movements were as delicate as a ballerina: 1. His movements were delicate 2. His movements were not delicate
# model says 'His movements were as delicate as a ballerina. His movements were delicate.' is more likely
#
#
# Q: His movements were as delicate as a linebacker: 1. His movements were delicate 2. His movements were not delicate
# model says 'His movements were as delicate as a linebacker. His movements were not delicate.' is more likely
#
#
# Q: The light was as bright as a glittering diamond: 1. The light was bright 2. The light was not bright
# model says 'The light was as bright as a glittering diamond. The light was bright.' is more likely
#
#
# Q: The light was as bright as an inkspot: 1. The light was bright 2. The light was not bright
# model says 'The light was as bright as an inkspot. The light was bright.' is more likely
#
#
# Q: The sprint was graceful as a fat man headed to his favorite all you can eat buffet.: 1. The sprint was slow but with a lot of effort. 2. There were many of competitors but the result was known beforehand.
# model says 'The sprint was graceful as a fat man headed to his favorite all you can eat buffet.. The sprint was slow but with a lot of effort..' is more likely
#
#
# Q: The sprint was as competitive as a Vladamir Putin election result.: 1. The sprint was slow but with a lot of effort. 2. There were many of competitors but the result was known beforehand.
# model says 'The sprint was as competitive as a Vladamir Putin election result.. The sprint was slow but with a lot of effort..' is more likely
#
#
# Q: The dinner's calorie count is as high as Mount Everest.: 1. The calorie count was very high. 2. The calorie count was very low.
# model says 'The dinner's calorie count is as high as Mount Everest.. The calorie count was very high..' is more likely
#
#
# Q: The dinner's calorie count is lower than Donald Trumps poll ratings.: 1. The calorie count was very high. 2. The calorie count was very low.
# model says 'The dinner's calorie count is lower than Donald Trumps poll ratings.. The calorie count was very low..' is more likely
#
#
# Q: The team's defense has as many holes in it as a Qanon conspiracy theory.: 1. The defense is of poor quality. 2. The defense did not let the other team through to achieve anything.
# model says 'The team's defense has as many holes in it as a Qanon conspiracy theory.. The defense is of poor quality..' is more likely
#
#
# Q: The team's defense is better at blocking progress than the Senate Majority Leader.: 1. The defense is of poor quality. 2. The defense did not let the other team through to achieve anything.
# model says 'The team's defense is better at blocking progress than the Senate Majority Leader.. The defense is of poor quality..' is more likely
#
#
# Q: She walked like an elephant: 1. She walked in a clumsy manner. 2. She walked with grace.
# model says 'She walked like an elephant. She walked with grace..' is more likely
#
#
# Q: She walked like a ballerina: 1. She walked in a clumsy manner. 2. She walked with grace.
# model says 'She walked like a ballerina. She walked with grace..' is more likely
#
#
# Q: The bottle is as clear as an ice cube: 1. The bottle is crystal clear 2. The bottle is not clear at all
# model says 'The bottle is as clear as an ice cube. The bottle is crystal clear.' is more likely
#
#
# Q: The bottle is as clear as sewer water: 1. The bottle is crystal clear 2. The bottle is not clear at all
# model says 'The bottle is as clear as sewer water. The bottle is crystal clear.' is more likely
#
#
# Q: Their relationship to the truth was akin to a pile of old extension cords: 1. They told a lot of lies and got tangled up in them 2. They told the truth and their story fit together
# model says 'Their relationship to the truth was akin to a pile of old extension cords. They told a lot of lies and got tangled up in them.' is more likely
#
#
# Q: Their relationship to the truth was akin to a brand new zipper: 1. They told a lot of lies and got tangled up in them 2. They told the truth and their story fit together
# model says 'Their relationship to the truth was akin to a brand new zipper. They told a lot of lies and got tangled up in them.' is more likely
#
#
# Q: The light given off had the ambiance of a condemned elevator: 1. The light given off was unappealing 2. The light given off was appealing
# model says 'The light given off had the ambiance of a condemned elevator. The light given off was unappealing.' is more likely
#
#
# Q: The light given off had the ambiance of a conservatory at twilight: 1. The light given off was unappealing 2. The light given off was appealing
# model says 'The light given off had the ambiance of a conservatory at twilight. The light given off was appealing.' is more likely
#
#
# Q: His eyes were the color of the night sky: 1. His eyes were blue 2. His eyes were brown
# model says 'His eyes were the color of the night sky. His eyes were blue.' is more likely
#
#
# Q: His eyes were the color of mud: 1. His eyes were blue 2. His eyes were brown
# model says 'His eyes were the color of mud. His eyes were brown.' is more likely
#
#
# Q: The boy is as clever as a fox: 1. the boy is smart 2. the boy is dumb
# model says 'The boy is as clever as a fox. the boy is smart.' is more likely
#
#
# Q: The boy is as clever as a twig on a tree: 1. the boy is smart 2. the boy is dumb
# model says 'The boy is as clever as a twig on a tree. the boy is smart.' is more likely
#
#
# Q: The template had the usefulness of a kitchen sink: 1. The template was very useful. 2. The template was totally useless.
# model says 'The template had the usefulness of a kitchen sink. The template was very useful..' is more likely
#
#
# Q: The template had the usefulness of window shopping: 1. The template was very useful. 2. The template was totally useless.
# model says 'The template had the usefulness of window shopping. The template was very useful..' is more likely
#
#
# Q: That cat has the killer instinct of a velociraptor.: 1. The cat was extremely deadly. 2. The cat was not very deadly.
# model says 'That cat has the killer instinct of a velociraptor.. The cat was extremely deadly..' is more likely
#
#
# Q: That cat has the killer instinct of a banana slug.: 1. The cat was extremely deadly. 2. The cat was not very deadly.
# model says 'That cat has the killer instinct of a banana slug.. The cat was extremely deadly..' is more likely
#
#
# Q: The stone was as heavy as A feather: 1. The stone is light in weight 2. The stone is very heavy
# model says 'The stone was as heavy as A feather. The stone is very heavy.' is more likely
#
#
# Q: The stone was as heavy as A ton of lead: 1. The stone is light in weight 2. The stone is very heavy
# model says 'The stone was as heavy as A ton of lead. The stone is very heavy.' is more likely
#
#
# Q: The actors in the play had all the talent of A drunken sailor: 1. The actors are not talented 2. The actors are very talented
# model says 'The actors in the play had all the talent of A drunken sailor. The actors are very talented.' is more likely
#
#
# Q: The actors in the play had all the talent of An Academy Award winner: 1. The actors are not talented 2. The actors are very talented
# model says 'The actors in the play had all the talent of An Academy Award winner. The actors are very talented.' is more likely
#
#
# Q: He is sharp like a tack.: 1. He is smart. 2. He is dumb.
# model says 'He is sharp like a tack.. He is smart..' is more likely
#
#
# Q: He is sharp like a eraser.: 1. He is smart. 2. He is dumb.
# model says 'He is sharp like a eraser.. He is smart..' is more likely
#
#
# Q: The glasses had the dirtiness of a bride on her wedding night: 1. The glasses are pretty dirty 2. The glases are clean
# model says 'The glasses had the dirtiness of a bride on her wedding night. The glasses are pretty dirty.' is more likely
#
#
# Q: The glasses had the dirtiness of a bride on her wedding day: 1. The glasses are pretty dirty 2. The glases are clean
# model says 'The glasses had the dirtiness of a bride on her wedding day. The glasses are pretty dirty.' is more likely
#
#
# Q: The tofu is as spicy as a hot poker on your tongue.: 1. The tofu is super spicy. 2. The tofu is not spicy at all.
# model says 'The tofu is as spicy as a hot poker on your tongue.. The tofu is not spicy at all..' is more likely
#
#
# Q: The tofu is as spicy as milk.: 1. The tofu is super spicy. 2. The tofu is not spicy at all.
# model says 'The tofu is as spicy as milk.. The tofu is not spicy at all..' is more likely
#
#
# Q: In sparring class I got kicked in the head like a horse kick.: 1. The kick was hard. 2. The kick was soft.
# model says 'In sparring class I got kicked in the head like a horse kick.. The kick was hard..' is more likely
#
#
# Q: In sparring class I got kicked in the head like a gnat landing.: 1. The kick was hard. 2. The kick was soft.
# model says 'In sparring class I got kicked in the head like a gnat landing.. The kick was hard..' is more likely
#
#
# Q: The boy is as polite as an inmate at a prison: 1. the boy is mean 2. the boy is nice
# model says 'The boy is as polite as an inmate at a prison. the boy is nice.' is more likely
#
#
# Q: The boy is as polite as a nun: 1. the boy is mean 2. the boy is nice
# model says 'The boy is as polite as a nun. the boy is nice.' is more likely
#
#
# Q: The house is as pretty as a dead porcupine: 1. the house is pretty 2. the house is ugly
# model says 'The house is as pretty as a dead porcupine. the house is ugly.' is more likely
#
#
# Q: The house is as pretty as a sunset: 1. the house is pretty 2. the house is ugly
# model says 'The house is as pretty as a sunset. the house is pretty.' is more likely
#
#
# Q: The blog post was as long as the Amazon River: 1. The blog post was very long. 2. The blog post was very short.
# model says 'The blog post was as long as the Amazon River. The blog post was very long..' is more likely
#
#
# Q: The blog post was as long as a power nap: 1. The blog post was very long. 2. The blog post was very short.
# model says 'The blog post was as long as a power nap. The blog post was very long..' is more likely
#
#
# Q: This drink has the sweetness of a chocolate coverd caramel: 1. It is very sweet 2. It is fairly bland
# model says 'This drink has the sweetness of a chocolate coverd caramel. It is very sweet.' is more likely
#
#
# Q: This drink has the sweetness of a piece of white bread: 1. It is very sweet 2. It is fairly bland
# model says 'This drink has the sweetness of a piece of white bread. It is very sweet.' is more likely
#
#
# Q: The headphones are as loud as a hurricane: 1. The headphones are loud 2. The headphones are quiet
# model says 'The headphones are as loud as a hurricane. The headphones are loud.' is more likely
#
#
# Q: The headphones are as loud as a pin drop: 1. The headphones are loud 2. The headphones are quiet
# model says 'The headphones are as loud as a pin drop. The headphones are loud.' is more likely

# %%
compute_stats(out_df, preds, labels)
out_df.to_csv(f"file.tsv", sep="\t", index=False)
# Out:
# overall accuracy:
# 0.612
# confusion matrix:
# correct forward 307 wrong forward 193 correct backward 285 wrong_backward 215

# %% [markdown]
# ## Finetuning

# %%
from peft import prepare_model_for_kbit_training

model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
from peft import LoraConfig, get_peft_model

config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["query_key_value"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)
print_trainable_parameters(model)

# %% [markdown]
# Let's load a common dataset, english quotes, to fine tune our model on famous quotes.

# %%
from datasets import load_dataset

data = load_dataset("Abirate/english_quotes")
data = data.map(lambda samples: tokenizer(samples["quote"]), batched=True)

# %% [markdown]
# Run the cell below to run the training! For the sake of the demo, we just ran it for few steps just to showcase how to use this integration with existing tools on the HF ecosystem.

# %%
import transformers

# needed for gpt-neo-x tokenizer
tokenizer.pad_token = tokenizer.eos_token

trainer = transformers.Trainer(
    model=model,
    train_dataset=data["train"],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=2,
        max_steps=10,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir="outputs",
        optim="paged_adamw_8bit"
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
trainer.train()

# %%
model_to_save = trainer.model.module if hasattr(trainer.model, 'module') else trainer.model  # Take care of distributed/parallel training
model_to_save.save_pretrained("outputs")

# %%
lora_config = LoraConfig.from_pretrained('outputs')
model = get_peft_model(model, lora_config)

# %%
text = "I'm selfish, impatient and a little insecure. "
device = "cuda:0"

inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=20)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
